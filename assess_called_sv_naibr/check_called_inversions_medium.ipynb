# %% [markdown]
# # Medium Inversions (NAIBR)
# Here, we visualize the inversions that were identified for the `medium` treatment across the range of depths.

# %%
library(ggplot2)
library(ggpattern)
library(dplyr)
library(ggpubr)
.size <- "medium"

# %% [markdown]
# These are the setup functions that process that data.

# %%
read_data <- function(size_treatment, depth){
    .depth <- paste("depth",depth, sep = "_")
    truthfile <- paste0("../simulated_variants/setup_inversions/", size_treatment, "/inv.", size_treatment,".vcf")
    samplesfile <- paste("../simulated_data/called_sv/naibr", size_treatment, .depth, "by_sample/inversions.bedpe", sep = "/")
    poolfile <- paste("../simulated_data/called_sv/naibr", size_treatment, .depth, "by_pop/inversions.bedpe", sep = "/")

    true_inversions <- read.table(truthfile, header = F)[,c(1,2,8)]
    true_inversions$V8 <- as.numeric(unlist(lapply(true_inversions$V8, function(X){gsub(".+END=", "", X)})))
    names(true_inversions) <- c("contig", "position_start", "position_end")
    true_inversions$sample <- "simulated_inversions"
    true_inversions$size <- size_treatment


    sample_inversions <- read.table(samplesfile, header = T)[,c(1:3,5)]
    names(sample_inversions) <- c("sample", "contig", "position_start", "position_end")
    if( nrow(sample_inversions) > 0){
        sample_inversions$size <- size_treatment
    }

    pooled_inversions <- read.table(poolfile, header = T)[,c(1:3,5)]
    names(pooled_inversions) <- c("sample", "contig", "position_start", "position_end")
    if( nrow(pooled_inversions) > 0){
        pooled_inversions$sample <- "pooled"
        pooled_inversions$size <- size_treatment
    }
    outdf <- rbind(true_inversions, sample_inversions, pooled_inversions)
    outdf$depth <- depth
    return(outdf)
}

read_all_data <- function(size_treatment){
    depth <- 0.5
    .data <- read_data(size_treatment, depth)    
    for(i in c(2,5,10,20)){
        .data <- rbind(.data, read_data(size_treatment, i))    
    }
    return(.data[,c(4,1,2,3,5,6)])
}

# %%
SV <- read_all_data(.size)
samplesSV <- SV[SV$sample != "simulated_inversions",]
head(samplesSV)
# Out:
#    sample    contig position_start position_end size   depth
# 17 sample_07 2R     18236266       18696239     medium 0.5
# 18 sample_07 2R     15861683       16301817     medium 0.5
# 19 sample_06 2R      9640473        9977961     medium 0.5
# 20 sample_01 2L     17055842       17423930     medium 0.5
# 21 sample_02 2L      1590748        1775795     medium 0.5
# 22 sample_09 2R     18236800       18697037     medium 0.5

# %% [markdown]
# Read in the sample and pool simulation inventory

# %%
inventory <- rbind(
    filter(read.table("../inversion_simulations.inventory", header = T), size == .size),
    filter(read.table("../inversion_simulations.pool.inventory", header = T), size == .size)
)
inventory <- rename(inventory, "simulated" = "present", "zygosity" = "state")

# set a default to false negatives, to be updated to true positives when conditions are met
inventory$assessment <- ifelse(inventory$simulated, "false negative", "true negative")
inventory$sample <- gsub("pool", "pooled", inventory$sample)
head(inventory)
# Out:
#   sample    size   contig inversion simulated zygosity assessment
# 1 sample_01 medium 2R     1         TRUE      het      false negative
# 2 sample_01 medium 2R     2         TRUE      het      false negative
# 3 sample_01 medium 2R     3         TRUE      het      false negative
# 4 sample_01 medium 2R     4         TRUE      het      false negative
# 5 sample_02 medium 2R     1         TRUE      het      false negative
# 6 sample_02 medium 2R     2         TRUE      het      false negative

# %%
# add depths to performance
# arrange() is for sanity-checking
performance <- inventory
performance$depth <- 0.5
for(i in c(2, 5, 10, 20)){
    inventory$depth <- i
    performance <- rbind(performance, inventory)
}
performance <- arrange(performance, sample, contig, inversion)
head(performance)
# Out:
#   sample size   contig inversion simulated zygosity assessment     depth
# 1 pooled medium 2L     1         TRUE      hom      false negative  0.5
# 2 pooled medium 2L     1         TRUE      hom      false negative  2.0
# 3 pooled medium 2L     1         TRUE      hom      false negative  5.0
# 4 pooled medium 2L     1         TRUE      hom      false negative 10.0
# 5 pooled medium 2L     1         TRUE      hom      false negative 20.0
# 6 pooled medium 2L     2         TRUE      hom      false negative  0.5

# %%
## read in truth data to transfer inversion breakpoints
x <- read_data(.size, 0.5)
for(i in c(2,5,10,20)){
    x <- rbind(x, read_data(.size, i))
}
x <- arrange(x, sample, contig, position_start, depth)
head(x)
# Out:
#   contig position_start position_end sample size   depth
# 1 2L     1590743        1775752      pooled medium 10.0
# 2 2L     1590744        1775795      pooled medium  0.5
# 3 2L     1591545        1776250      pooled medium  2.0
# 4 2L     1591545        1776250      pooled medium  5.0
# 5 2L     1591545        1776256      pooled medium 20.0
# 6 2L     6436529        6636805      pooled medium  0.5

# %%
truth <- group_by(x[x$sample == "simulated_inversions",], contig, depth) %>% mutate(inversion = 1:n()) %>% ungroup()
head(truth)
# Out:
#   contig position_start position_end sample               size   depth
# 1 2L     1591146        1776073      simulated_inversions medium  0.5
# 2 2L     1591146        1776073      simulated_inversions medium  2.0
# 3 2L     1591146        1776073      simulated_inversions medium  5.0
# 4 2L     1591146        1776073      simulated_inversions medium 10.0
# 5 2L     1591146        1776073      simulated_inversions medium 20.0
# 6 2L     6436329        6636405      simulated_inversions medium  0.5
#   inversion
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 2

# %%
# merge it all together
performance <- merge(performance,truth[,c(-4,-5)], by = c("contig", "inversion", "depth"))
performance$id <- as.integer(as.factor(performance$position_start))
performance <- arrange(performance, contig, inversion, "sample", depth)[, c(1,2,11,3,4:10)]
head(performance, 15)
# Out:
#    contig inversion id depth sample    size   simulated zygosity assessment
# 1  2L     1         1  0.5   pooled    medium TRUE      hom      false negative
# 2  2L     1         1  0.5   sample_01 medium TRUE      hom      false negative
# 3  2L     1         1  0.5   sample_07 medium TRUE      hom      false negative
# 4  2L     1         1  0.5   sample_05 medium TRUE      hom      false negative
# 5  2L     1         1  0.5   sample_10 medium TRUE      hom      false negative
# 6  2L     1         1  0.5   sample_08 medium TRUE      hom      false negative
# 7  2L     1         1  0.5   sample_03 medium TRUE      hom      false negative
# 8  2L     1         1  0.5   sample_09 medium TRUE      hom      false negative
# 9  2L     1         1  0.5   sample_04 medium TRUE      hom      false negative
# 10 2L     1         1  0.5   sample_02 medium TRUE      hom      false negative
# 11 2L     1         1  0.5   sample_06 medium TRUE      hom      false negative
# 12 2L     1         1  2.0   sample_01 medium TRUE      hom      false negative
# 13 2L     1         1  2.0   sample_03 medium TRUE      hom      false negative
# 14 2L     1         1  2.0   sample_08 medium TRUE      hom      false negative
# 15 2L     1         1  2.0   sample_05 medium TRUE      hom      false negative
#    position_start position_end
# 1  1591146        1776073
# 2  1591146        1776073
# 3  1591146        1776073
# 4  1591146        1776073
# 5  1591146        1776073
# 6  1591146        1776073
# 7  1591146        1776073
# 8  1591146        1776073
# 9  1591146        1776073
# 10 1591146        1776073
# 11 1591146        1776073
# 12 1591146        1776073
# 13 1591146        1776073
# 14 1591146        1776073
# 15 1591146        1776073

# %% [markdown]
# ### Assess the performance of identified inversions

# %%
false_positives <- samplesSV[0,]

for(i in 1:nrow(samplesSV)){
    .row <- samplesSV[i,]
    query <- which(
        performance$sample == .row$sample &
        performance$depth == .row$depth &
        performance$contig == .row$contig &
        performance$position_start - 500 <= .row$position_start &
        performance$position_end + 500 >= .row$position_end
    )
    if(length(query) > 0 && performance$simulated[query]){
        performance$assessment[query] <- "true positive"
    } else {
        performance$assessment[query] <- "false positive"
        false_positives <- rbind(false_positives, .row)
    }
}
head(performance)
head(false_positives)
# Out:
#   contig inversion id depth sample    size   simulated zygosity assessment
# 1 2L     1         1  0.5   pooled    medium TRUE      hom      true positive
# 2 2L     1         1  0.5   sample_01 medium TRUE      hom      false negative
# 3 2L     1         1  0.5   sample_07 medium TRUE      hom      false negative
# 4 2L     1         1  0.5   sample_05 medium TRUE      hom      false negative
# 5 2L     1         1  0.5   sample_10 medium TRUE      hom      false negative
# 6 2L     1         1  0.5   sample_08 medium TRUE      hom      false negative
#   position_start position_end
# 1 1591146        1776073
# 2 1591146        1776073
# 3 1591146        1776073
# 4 1591146        1776073
# 5 1591146        1776073
# 6 1591146        1776073
#      sample contig position_start position_end size depth

# %%
performance[performance$assessment == "true positive",]
# Out:
#     contig inversion id depth sample    size   simulated zygosity assessment
# 1   2L     1         1   0.5  pooled    medium TRUE      hom      true positive
# 10  2L     1         1   0.5  sample_02 medium TRUE      hom      true positive
# 13  2L     1         1   2.0  sample_03 medium TRUE      hom      true positive
# 16  2L     1         1   2.0  sample_02 medium TRUE      hom      true positive
# 17  2L     1         1   2.0  sample_04 medium TRUE      hom      true positive
# 18  2L     1         1   2.0  sample_10 medium TRUE      hom      true positive
# 20  2L     1         1   2.0  pooled    medium TRUE      hom      true positive
# 23  2L     1         1   5.0  sample_04 medium TRUE      hom      true positive
# 25  2L     1         1   5.0  sample_03 medium TRUE      hom      true positive
# 26  2L     1         1   5.0  sample_05 medium TRUE      hom      true positive
# 27  2L     1         1   5.0  sample_07 medium TRUE      hom      true positive
# 29  2L     1         1   5.0  sample_01 medium TRUE      hom      true positive
# 30  2L     1         1   5.0  sample_02 medium TRUE      hom      true positive
# 31  2L     1         1   5.0  sample_08 medium TRUE      hom      true positive
# 32  2L     1         1   5.0  pooled    medium TRUE      hom      true positive
# 33  2L     1         1   5.0  sample_10 medium TRUE      hom      true positive
# 34  2L     1         1  10.0  sample_06 medium TRUE      hom      true positive
# 35  2L     1         1  10.0  sample_07 medium TRUE      hom      true positive
# 36  2L     1         1  10.0  sample_04 medium TRUE      hom      true positive
# 37  2L     1         1  10.0  sample_05 medium TRUE      hom      true positive
# 38  2L     1         1  10.0  sample_09 medium TRUE      hom      true positive
# 39  2L     1         1  10.0  sample_01 medium TRUE      hom      true positive
# 40  2L     1         1  10.0  sample_03 medium TRUE      hom      true positive
# 41  2L     1         1  10.0  sample_08 medium TRUE      hom      true positive
# 42  2L     1         1  10.0  sample_10 medium TRUE      hom      true positive
# 43  2L     1         1  10.0  sample_02 medium TRUE      hom      true positive
# 44  2L     1         1  10.0  pooled    medium TRUE      hom      true positive
# 45  2L     1         1  20.0  sample_07 medium TRUE      hom      true positive
# 46  2L     1         1  20.0  sample_06 medium TRUE      hom      true positive
# 47  2L     1         1  20.0  sample_08 medium TRUE      hom      true positive
# ⋮   ⋮      ⋮         ⋮  ⋮     ⋮         ⋮      ⋮         ⋮        ⋮
# 769 3R     2         14 20    sample_06 medium TRUE      hom      true positive
# 784 3R     3         15  2    sample_06 medium TRUE      hom      true positive
# 785 3R     3         15  2    sample_02 medium TRUE      hom      true positive
# 786 3R     3         15  2    sample_04 medium TRUE      hom      true positive
# 787 3R     3         15  2    sample_08 medium TRUE      het      true positive
# 789 3R     3         15  2    sample_01 medium TRUE      hom      true positive
# 795 3R     3         15  5    sample_04 medium TRUE      hom      true positive
# 796 3R     3         15  5    sample_06 medium TRUE      hom      true positive
# 797 3R     3         15  5    sample_08 medium TRUE      het      true positive
# 799 3R     3         15  5    sample_02 medium TRUE      hom      true positive
# 801 3R     3         15  5    sample_07 medium TRUE      het      true positive
# 802 3R     3         15  5    pooled    medium TRUE      hom      true positive
# 803 3R     3         15  5    sample_01 medium TRUE      hom      true positive
# 805 3R     3         15 10    sample_04 medium TRUE      hom      true positive
# 806 3R     3         15 10    sample_05 medium TRUE      het      true positive
# 808 3R     3         15 10    sample_02 medium TRUE      hom      true positive
# 809 3R     3         15 10    sample_03 medium TRUE      het      true positive
# 810 3R     3         15 10    sample_07 medium TRUE      het      true positive
# 811 3R     3         15 10    sample_09 medium TRUE      het      true positive
# 812 3R     3         15 10    sample_01 medium TRUE      hom      true positive
# 814 3R     3         15 10    pooled    medium TRUE      hom      true positive
# 815 3R     3         15 20    pooled    medium TRUE      hom      true positive
# 816 3R     3         15 20    sample_09 medium TRUE      het      true positive
# 818 3R     3         15 20    sample_01 medium TRUE      hom      true positive
# 819 3R     3         15 20    sample_02 medium TRUE      hom      true positive
# 821 3R     3         15 20    sample_08 medium TRUE      het      true positive
# 822 3R     3         15 20    sample_04 medium TRUE      hom      true positive
# 823 3R     3         15 20    sample_07 medium TRUE      het      true positive
# 824 3R     3         15 20    sample_03 medium TRUE      het      true positive
# 825 3R     3         15 20    sample_06 medium TRUE      hom      true positive
#     position_start position_end
# 1   1591146        1776073
# 10  1591146        1776073
# 13  1591146        1776073
# 16  1591146        1776073
# 17  1591146        1776073
# 18  1591146        1776073
# 20  1591146        1776073
# 23  1591146        1776073
# 25  1591146        1776073
# 26  1591146        1776073
# 27  1591146        1776073
# 29  1591146        1776073
# 30  1591146        1776073
# 31  1591146        1776073
# 32  1591146        1776073
# 33  1591146        1776073
# 34  1591146        1776073
# 35  1591146        1776073
# 36  1591146        1776073
# 37  1591146        1776073
# 38  1591146        1776073
# 39  1591146        1776073
# 40  1591146        1776073
# 41  1591146        1776073
# 42  1591146        1776073
# 43  1591146        1776073
# 44  1591146        1776073
# 45  1591146        1776073
# 46  1591146        1776073
# 47  1591146        1776073
# ⋮   ⋮              ⋮
# 769 22722816       22831351
# 784 24237377       24380766
# 785 24237377       24380766
# 786 24237377       24380766
# 787 24237377       24380766
# 789 24237377       24380766
# 795 24237377       24380766
# 796 24237377       24380766
# 797 24237377       24380766
# 799 24237377       24380766
# 801 24237377       24380766
# 802 24237377       24380766
# 803 24237377       24380766
# 805 24237377       24380766
# 806 24237377       24380766
# 808 24237377       24380766
# 809 24237377       24380766
# 810 24237377       24380766
# 811 24237377       24380766
# 812 24237377       24380766
# 814 24237377       24380766
# 815 24237377       24380766
# 816 24237377       24380766
# 818 24237377       24380766
# 819 24237377       24380766
# 821 24237377       24380766
# 822 24237377       24380766
# 823 24237377       24380766
# 824 24237377       24380766
# 825 24237377       24380766

# %% [markdown]
# This is extra formatting we need to do to get it to plot correctly

# %%
performance$sample <- gsub("sample_", "", performance$sample)
performance$sample <- gsub("pooled", "11", performance$sample)
performance$sample <- as.integer(performance$sample)

simulated_for_plot <- truth
simulated_for_plot$assessment <- "true positive"
simulated_for_plot$sample <- 0
simulated_for_plot <- simulated_for_plot[simulated_for_plot$depth == 20, -5]
head(simulated_for_plot)
# Out:
#   contig position_start position_end sample depth inversion assessment
# 1 2L      1591146        1776073     0      20    1         true positive
# 2 2L      6436329        6636405     0      20    2         true positive
# 3 2L     17056243       17424245     0      20    3         true positive
# 4 2L     20404853       20474308     0      20    4         true positive
# 5 2R      9640874        9978281     0      20    1         true positive
# 6 2R     15862083       16302028     0      20    2         true positive

# %% [markdown]
# ### Single-Sample Detection
# Let's first visualize what detection looked like across the genome. Here, we facet across contigs and show all the depths at once. Since the small inversions are indeed quite small, for visualization purposes, we'll make each of them 100 kb bigger.

# %%
plot_inversions <- function(data, groundtruth, size_treatment){
    options(warn = -1, repr.plot.width = 19, repr.plot.height = 10)
    .tbl <- filter(data, assessment == "true positive") %>% select(contig, inversion, position_start, position_end, depth, assessment, sample)
    
    rbind(.tbl, groundtruth) %>%

    ggplot(
        aes(
            x = sample,
            ymin = position_start,
            ymax = position_end,+100000,
            color = as.factor(depth),
        )
    ) +
        geom_linerange(position = position_dodge(0.7), linewidth = 1.5) +
        coord_flip() +
        scale_color_brewer(name = "sequencing depth", palette = "Set2") +
        scale_x_continuous(breaks = 0:11,limits = c(0, 11)) +
        scale_y_continuous(labels = scales::comma) +
        theme_light() +
        theme(
            panel.grid.major.y = element_blank(),
            legend.position = "top",
            panel.grid.minor.y = element_line(color = "gray80", size = 0.5)
        ) +
        labs(
            title = "Simulated and Called Inversions Across the Genome",
            subtitle = paste0("Size: ", size_treatment),
            y = "genomic position (bp)",
            caption = "sample 0 = groundtruth | sample 11 = pooled"
        ) + 
        facet_grid(cols = vars(contig))
}

# %%
plot_inversions(performance, simulated_for_plot, .size)
# Out:
# plot without title

# %% [markdown]
# What does this look like as a heatmap of true/false positive/negative?

# %%
plot_samples_matrix <- function(data, size_treatment){
    options(warn = -1, repr.plot.width = 10, repr.plot.height = 15)
    .data <- data[data$sample != 11,]
    axis_ticks <- factor(paste0("sample_", sprintf("%02d", 1:10)))
    ggplot(.data, aes(y = sample, x = id, fill = assessment, pattern = zygosity)) +
        geom_tile_pattern(
            pattern_color = NA,
            color = "white",
            pattern_fill = "black",
            pattern_angle = 45,
            pattern_density = 0.5,
            pattern_spacing = 0.025,
            pattern_key_scale_factor = 1
        ) +
        theme_light() +
        labs(title = "By-Sample Inversion Detection", subtitle = paste(size_treatment, "inversions detected in individual samples, as a function of zygotic state.")) +
        scale_fill_manual(values = c("false negative" = "#eaf398ff", "true negative" = "grey70", "true positive" = "#90aed8")) +
        scale_pattern_manual(values = c("het" = "circle", "hom" = "none")) +
        scale_x_discrete(name = "Inversion") +
        scale_y_discrete(limits = axis_ticks, breaks = axis_ticks) +
        coord_cartesian(xlim = c(1, max(data$id)), expand = F) +
        theme(
            panel.grid.major = element_blank(),
            panel.grid.minor = element_blank()
        ) +
        facet_grid(rows = vars(depth))
}

# %%
plot_samples_matrix(performance, .size)
# Out:
# plot without title

# %% [markdown]
# ### Pooled Sample Detection

# %%
plot_pools_matrix <- function(data, size_treatment){
    options(warn = -1, repr.plot.width = 15, repr.plot.height = 10)
    .data <- data[data$sample == 11,]
    .data$contig <- gsub("2L", "2L (all homozygous)", .data$contig)
    .data$contig <- gsub("2R", "2R (all heterozygous)", .data$contig)
    .data$contig <- gsub("3L", "3L (inversions common)", .data$contig)
    .data$contig <- gsub("3R", "3R (inversions rare)", .data$contig)
 
    ggplot(.data, aes(y = 1, x = inversion, fill = assessment)) +
        geom_tile(color = "white", linewidth = 1.5) +
        theme_light() +
        labs(title = "Pooled-Sample Detection", subtitle = paste(size_treatment, "inversions detected in sample-pooled data, as a function of inversion frequency in the population.")) +
        scale_fill_manual(values = c("false negative" = "grey70", "true positive" = "#90aed8")) +
        scale_y_continuous(breaks = 1, name = "Assessment") +
        scale_x_discrete(name = "Inversion") +
        theme(
            panel.grid.major = element_blank(),
            panel.grid.minor = element_blank(),
            axis.text.y = element_blank(),
            axis.ticks.y = element_blank()
        ) +
        coord_cartesian(xlim = c(1, max(data$inversion)), expand = F) +
        facet_grid(cols = vars(contig), rows = vars(depth))
}

# %%
plot_pools_matrix(performance, .size)
# Out:
# plot without title

# %% [markdown]
# Write this all to a file to tease apart later

# %%
write.csv(performance, file = paste0(.size, ".sv.naibr.assessment"), quote = F, row.names = F)
# Out:
# [1] TRUE
